# %% [markdown]
# # Anonymisation de données

# %% [markdown]
# ## Imports

# %%
from pprint import pprint
from faker import Faker
from faker.providers import internet

# %% [markdown]
# "Faker is a Python package that generates fake data for you. Whether you need to bootstrap your database, create good-looking XML documents, fill-in your persistence to stress test it, or anonymize data taken from a production service, Faker is for you."
#
# https://faker.readthedocs.io/en/master/

# %% [markdown]
# "Use `faker.Faker()` to create and initialize a faker generator, which can generate data by accessing properties named after the type of data you want."

# %%
fake = Faker()

# %% [markdown]
# ## Créer un faux nom

# %%
print(fake.name())
# Out:
# Kristin Smith

# %%
# Il est possible de créer plusieurs faux noms, ici en français, avec une boucle.
fake_fr = Faker('fr_FR')
for _ in range(10):
    print(fake_fr.name())
# Out:
# Lucy Breton de la Dufour
# Jacques Petitjean
# Simone Jacquot
# Louise Boucher du Chevalier
# Adrienne Le Lemaître
# Laetitia Poulain
# Adrien Weber
# Dominique Garnier
# Joseph Samson de Marin
# Valentine Baudry

# %%
# Même chose en néerlandais.
fake_nl = Faker('nl_NL')
for _ in range(10):
    print(fake_nl.name())
# Out:
# Alex van Laarhoven-van Goerle
# Seth Luitgardis van Neustrië-van der Velde
# Mika Smith
# Annabel van Haspengouw-van Berkel
# Faye Palman
# Jenna Arent
# Jesper van de Wiel-Chrodtrud
# Fien Korsman
# Lena Kuipers
# Berend van Breukeleveen-Ariens

# %% [markdown]
# ## Créer une fausse adresse

# %%
# Pour créer une fausse adresse.
print(fake.address())
# Out:
# 46824 Pittman Forest Suite 337
# East Valerie, MT 74387

# %% [markdown]
# ## Créer une fausse adresse IP

# %%
fake.add_provider(internet)
print(fake.ipv4_public())
# Out:
# 202.245.84.153

# %% [markdown]
# ## Créer un faux profil complet

# %%
profile = fake_fr.simple_profile()
pprint(profile)
# Out:
# {'address': '86, rue Alexandrie Prévost\n69900 Grégoire',
#  'birthdate': datetime.date(2023, 1, 10),
#  'mail': 'fwagner@ifrance.com',
#  'name': 'Émilie-Constance Leroy',
#  'sex': 'F',
#  'username': 'isabelle68'}
